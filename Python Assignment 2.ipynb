# %% [markdown]
# # <center>Python Assignment 2

# %% [markdown]
# ## Name: Raees Rizwan

# %% [markdown]
# **1. Create the below pattern using nested for loop in Python.**

# %% [markdown]
# ![traingle.JPG](attachment:traingle.JPG)

# %%
for i in range(1,6):
    for j in range(i):
        print('*',end=" ")
    print("")
for i in range(4,0,-1):
    for j in range(i):
        print('*',end=" ")
    print("")
# Out:
# *
# * *
# * * *
# * * * *
# * * * * *
# * * * *
# * * *
# * *
# *

# %% [markdown]
# **2. Write a Python program to reverse a word after accepting the input from the user.**
#
# **Sample Output:**
#
# **Input word: ineuron**
#
# **Output: norueni**

# %%
word = input('Input word: ')

rev_word = []
for i in range(len(word)-1,-1,-1):
     rev_word.append(word[i])
   
print('Output: ',rev_word)
# Out:
# Input word: ineuron
# Output:  ['n', 'o', 'r', 'u', 'e', 'n', 'i']

# %% [markdown]
# *Alternative solution using slice command*

# %%
word = input('Input word: ')

rev_word = word[::-1]

print('Output: ',rev_word)
# Out:
# Input word: ineuron
# Output:  norueni
